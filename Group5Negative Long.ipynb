# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
Quantities = pd.read_csv('/Users/xiaoyanglong/Downloads/store_data.csv', index_col='State')
print(Quantities)
print(Quantities.columns)
# Out:
#             Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# State
# Kentucky         1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# Kentucky         2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# California       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# Florida          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# Florida          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...            ...             ...         ...         ...             ...
# Florida       9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# California    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# California    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# California    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# California    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
# ...

# %%
Illinois = Quantities[Quantities.index == 'Illinois']
Illinois
# Out:
#           Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# State
# Illinois      42  CA-2017-120999   9/10/2017   9/15/2017  Standard Class
# Illinois      67  US-2015-164175   4/30/2015    5/5/2015  Standard Class
# Illinois      85  US-2017-119662  11/13/2017  11/16/2017     First Class
# Illinois     100  CA-2016-158568   8/29/2016    9/2/2016  Standard Class
# Illinois     101  CA-2016-158568   8/29/2016    9/2/2016  Standard Class
# ...          ...             ...         ...         ...             ...
# Illinois    9872  CA-2017-146269   10/6/2017   10/6/2017        Same Day
# Illinois    9873  CA-2017-146269   10/6/2017   10/6/2017        Same Day
# Illinois    9896  CA-2014-115049   9/26/2014   10/1/2014  Standard Class
# Illinois    9897  CA-2014-156342   6/17/2014   6/20/2014    Second Class
# Illinois    9923  US-2017-162124    5/6/2017   5/10/2017  Standard Class
#
#          Customer ID       Customer Name      Segment        Country  \
# State
# ...

# %%
np.array(Illinois['Sales'][0:10])
# Out:
# array([147.168, 213.115, 230.376,  64.624,  95.976,   1.788, 339.96 ,
#        617.7  ,  52.448,  20.16 ])

# %%
# Illnois.plot.area(y=['Sales'])
plt.title('Sales Amount in Illnois', fontsize = 16, fontweight = 'bold')
plt.xlabel('Sales Record', fontsize=16, fontweight='bold')
plt.ylabel('Sales Amount', fontsize=16, fontweight='bold')
plt.plot(np.array(Illinois['Sales'][0:-1]))
plt.show()
